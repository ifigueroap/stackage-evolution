# %%
import pandas as pd
import os
import matplotlib
import matplotlib.pyplot as plt
import requests
from datetime import datetime, timedelta
from pandas.plotting import register_matplotlib_converters
from htmldate import find_date
from util.api import get_lts_list,make_columns_monad
from selenium import webdriver
import requests
from bs4 import BeautifulSoup
import re
# %matplotlib inline
plt.style.use('classic')

# %%
lts_list = get_lts_list()
df_list = []
df_by_category_list = []

print(lts_list)

for idx, lts in enumerate(lts_list):
    df = pd.read_pickle(f'../../data/dfs/lts-{lts}/lts-{lts}.df')
    print(f'../../data/dfs/lts-{lts}/lts-{lts}.df')
    print(df)
    df_list.append(df)
# Out:
# Index(['0-7', '2-22', '3-22', '6-35', '7-24', '9-21', '11-22', '12-14',
#        '12-26', '13-11', '13-19', '14-27', '15-3', '16-11', '16-31', '17-2',
#        '18-6', '18-8', '18-28', '19-33', '20-11', '20-12', '20-24', '20-26',
#        '21-7', '21-11', '21-21', '21-25', '22-6', '22-20', '22-27', '22-43',
#        '22-44', '23-28', '24-11', '24-37'],
#       dtype='str')
# ../../data/dfs/lts-0-7/lts-0-7.df
#                                                  package  version  \
# AC-Vector-2.3.2                                AC-Vector    2.3.2
# BlastHTTP-1.0.1                                BlastHTTP    1.0.1
# BlogLiterately-0.7.1.7                    BlogLiterately  0.7.1.7
# BlogLiterately-diagrams-0.1.4.3  BlogLiterately-diagrams  0.1.4.3
# Boolean-0.2.3                                    Boolean    0.2.3
# ...                                                  ...      ...
# zip-archive-0.2.3.5                          zip-archive  0.2.3.5
# zlib-0.5.4.2                                        zlib  0.5.4.2
# zlib-bindings-0.1.1.5                      zlib-bindings  0.1.1.5
# zlib-enum-0.2.3.1                              zlib-enum  0.2.3.1
# zlib-lens-0.1                                  zlib-lens      0.1
#
#                                       stability  \
# AC-Vector-2.3.2                  [experimental]
# BlastHTTP-1.0.1                              []
# BlogLiterately-0.7.1.7           [experimental]
# BlogLiterately-diagrams-0.1.4.3              []
# Boolean-0.2.3                    [experimental]
# ...                                         ...
# zip-archive-0.2.3.5                          []
# zlib-0.5.4.2                                 []
# zlib-bindings-0.1.1.5            [experimental]
# zlib-enum-0.2.3.1                [experimental]
# zlib-lens-0.1                                []
#
#                                                                         cabal-file  \
# AC-Vector-2.3.2                  /home/giacamole/projects/memoria-haskell/stack...
# BlastHTTP-1.0.1                  /home/giacamole/projects/memoria-haskell/stack...
# BlogLiterately-0.7.1.7           /home/giacamole/projects/memoria-haskell/stack...
# BlogLiterately-diagrams-0.1.4.3  /home/giacamole/projects/memoria-haskell/stack...
# Boolean-0.2.3                    /home/giacamole/projects/memoria-haskell/stack...
# ...                                                                            ...
# zip-archive-0.2.3.5              /home/giacamole/projects/memoria-haskell/stack...
# zlib-0.5.4.2                     /home/giacamole/projects/memoria-haskell/stack...
# zlib-bindings-0.1.1.5            /home/giacamole/projects/memoria-haskell/stack...
# zlib-enum-0.2.3.1                /home/giacamole/projects/memoria-haskell/stack...
# zlib-lens-0.1                    /home/giacamole/projects/memoria-haskell/stack...
#
#                                                         categories  \
# AC-Vector-2.3.2                  [data, math, numerical, graphics]
# BlastHTTP-1.0.1                                   [bioinformatics]
# BlogLiterately-0.7.1.7                                       [web]
# BlogLiterately-diagrams-0.1.4.3                              [web]
# Boolean-0.2.3                                               [data]
# ...                                                            ...
# zip-archive-0.2.3.5                                        [codec]
# zlib-0.5.4.2                                               [codec]
# zlib-bindings-0.1.1.5                                      [codec]
# zlib-enum-0.2.3.1                 [codec, compression, enumerator]
# zlib-lens-0.1                                              [codec]
#
#                                                                               deps  \
# AC-Vector-2.3.2                                                             [base]
# BlastHTTP-1.0.1                  [HTTP, base, biocore, blastxml, bytestring, co...
# BlogLiterately-0.7.1.7           [BlogLiterately, HaXml, base, base, blaze-html...
# BlogLiterately-diagrams-0.1.4.3  [BlogLiterately, BlogLiterately-diagrams, base...
# Boolean-0.2.3                                                               [base]
# ...                                                                            ...
# zip-archive-0.2.3.5              [array, base, binary, bytestring, digest, dire...
# zlib-0.5.4.2                                                    [base, bytestring]
# zlib-bindings-0.1.1.5                                     [base, bytestring, zlib]
# zlib-enum-0.2.3.1                [base, bytestring, enumerator, transformers, z...
# zlib-lens-0.1                                       [base, bytestring, lens, zlib]
#
#                                                                   provided-modules  \
# AC-Vector-2.3.2                  [Data.BoundingBox.B1, Data.BoundingBox.B2, Dat...
# BlastHTTP-1.0.1                                                    [Bio.BlastHTTP]
# BlogLiterately-0.7.1.7           [Paths_BlogLiterately, Text.BlogLiterately, Te...
# BlogLiterately-diagrams-0.1.4.3                     [Text.BlogLiterately.Diagrams]
# Boolean-0.2.3                    [Data.Boolean, Data.Boolean.Numbers, Data.Bool...
# ...                                                                            ...
# zip-archive-0.2.3.5                                            [Codec.Archive.Zip]
# zlib-0.5.4.2                     [Codec.Compression.GZip, Codec.Compression.Zli...
# zlib-bindings-0.1.1.5                            [Codec.Zlib, Codec.Zlib.Lowlevel]
# zlib-enum-0.2.3.1                                                [Codec.Zlib.Enum]
# zlib-lens-0.1                                        [Codec.Compression.Zlib.Lens]
#
#                                          src-dirs          main-modules  \
# AC-Vector-2.3.2                               [.]                    []
# BlastHTTP-1.0.1                             [src]                    []
# BlogLiterately-0.7.1.7                [main, src]   [BlogLiterately.hs]
# BlogLiterately-diagrams-0.1.4.3  [src, src/tools]  [BlogLiteratelyD.hs]
# Boolean-0.2.3                               [src]                    []
# ...                                           ...                   ...
# zip-archive-0.2.3.5                      [., src]              [Zip.hs]
# zlib-0.5.4.2                                   []                    []
# zlib-bindings-0.1.1.5                          []                    []
# zlib-enum-0.2.3.1                              []             [test.hs]
# zlib-lens-0.1                               [src]                    []
#
#                                  mtl-direct  ...  \
# AC-Vector-2.3.2                           0  ...
# BlastHTTP-1.0.1                           1  ...
# BlogLiterately-0.7.1.7                    1  ...
# BlogLiterately-diagrams-0.1.4.3           0  ...
# Boolean-0.2.3                             0  ...
# ...                                     ...  ...
# zip-archive-0.2.3.5                       1  ...
# zlib-0.5.4.2                              0  ...
# zlib-bindings-0.1.1.5                     0  ...
# zlib-enum-0.2.3.1                         0  ...
# zlib-lens-0.1                             0  ...
#
#                                 Control.Monad.Trans.Writer.Lazy  \
# AC-Vector-2.3.2                                               0
# BlastHTTP-1.0.1                                               0
# BlogLiterately-0.7.1.7                                        0
# BlogLiterately-diagrams-0.1.4.3                               0
# Boolean-0.2.3                                                 0
# ...                                                         ...
# zip-archive-0.2.3.5                                           0
# zlib-0.5.4.2                                                  0
# zlib-bindings-0.1.1.5                                         0
# zlib-enum-0.2.3.1                                             0
# zlib-lens-0.1                                                 0
#
#                                 Control.Monad.Trans.Writer.Strict  \
# AC-Vector-2.3.2                                                 0
# BlastHTTP-1.0.1                                                 0
# BlogLiterately-0.7.1.7                                          0
# BlogLiterately-diagrams-0.1.4.3                                 0
# Boolean-0.2.3                                                   0
# ...                                                           ...
# zip-archive-0.2.3.5                                             0
# zlib-0.5.4.2                                                    0
# zlib-bindings-0.1.1.5                                           0
# zlib-enum-0.2.3.1                                               0
# zlib-lens-0.1                                                   0
#
#                                 Control.Monad System.IO  \
# AC-Vector-2.3.2                             0         0
# BlastHTTP-1.0.1                             1         0
# BlogLiterately-0.7.1.7                      1         1
# BlogLiterately-diagrams-0.1.4.3             0         1
# Boolean-0.2.3                               0         0
# ...                                       ...       ...
# zip-archive-0.2.3.5                         1         1
# zlib-0.5.4.2                                1         0
# zlib-bindings-0.1.1.5                       1         0
# zlib-enum-0.2.3.1                           1         1
# zlib-lens-0.1                               0         0
#
#                                 Control.Monad.Trans.Control  \
# AC-Vector-2.3.2                                           0
# BlastHTTP-1.0.1                                           0
# BlogLiterately-0.7.1.7                                    0
# BlogLiterately-diagrams-0.1.4.3                           0
# Boolean-0.2.3                                             0
# ...                                                     ...
# zip-archive-0.2.3.5                                       0
# zlib-0.5.4.2                                              0
# zlib-bindings-0.1.1.5                                     0
# zlib-enum-0.2.3.1                                         0
# zlib-lens-0.1                                             0
#
#                                 Control.Monad.Free  Control.Monad.Free.Ap  \
# AC-Vector-2.3.2                                  0                      0
# BlastHTTP-1.0.1                                  0                      0
# BlogLiterately-0.7.1.7                           0                      0
# BlogLiterately-diagrams-0.1.4.3                  0                      0
# Boolean-0.2.3                                    0                      0
# ...                                            ...                    ...
# zip-archive-0.2.3.5                              0                      0
# zlib-0.5.4.2                                     0                      0
# zlib-bindings-0.1.1.5                            0                      0
# zlib-enum-0.2.3.1                                0                      0
# zlib-lens-0.1                                    0                      0
#
#                                  Control.Monad.Free.Church  \
# AC-Vector-2.3.2                                          0
# BlastHTTP-1.0.1                                          0
# BlogLiterately-0.7.1.7                                   0
# BlogLiterately-diagrams-0.1.4.3                          0
# Boolean-0.2.3                                            0
# ...                                                    ...
# zip-archive-0.2.3.5                                      0
# zlib-0.5.4.2                                             0
# zlib-bindings-0.1.1.5                                    0
# zlib-enum-0.2.3.1                                        0
# zlib-lens-0.1                                            0
#
#                                  Control.Monad.Free.Class  \
# AC-Vector-2.3.2                                         0
# BlastHTTP-1.0.1                                         0
# BlogLiterately-0.7.1.7                                  0
# BlogLiterately-diagrams-0.1.4.3                         0
# Boolean-0.2.3                                           0
# ...                                                   ...
# zip-archive-0.2.3.5                                     0
# zlib-0.5.4.2                                            0
# zlib-bindings-0.1.1.5                                   0
# zlib-enum-0.2.3.1                                       0
# zlib-lens-0.1                                           0
#
#                                  Control.Monad.Free.TH
# AC-Vector-2.3.2                                      0
# BlastHTTP-1.0.1                                      0
# BlogLiterately-0.7.1.7                               0
# BlogLiterately-diagrams-0.1.4.3                      0
# Boolean-0.2.3                                        0
# ...                                                ...
# zip-archive-0.2.3.5                                  0
# zlib-0.5.4.2                                         0
# zlib-bindings-0.1.1.5                                0
# zlib-enum-0.2.3.1                                    0
# zlib-lens-0.1                                        0
#
# [827 rows x 65 columns]
# ../../data/dfs/lts-2-22/lts-2-22.df
#                              package   version       stability  \
# AC-Vector-2.3.2            AC-Vector     2.3.2  [experimental]
# BlastHTTP-1.0.1            BlastHTTP     1.0.1              []
# Boolean-0.2.3                Boolean     0.2.3  [experimental]
# BoundedChan-1.0.3.0      BoundedChan   1.0.3.0        [stable]
# Cabal-1.18.1.5                 Cabal  1.18.1.5              []
# ...                              ...       ...             ...
# zip-archive-0.2.3.7      zip-archive   0.2.3.7              []
# zlib-0.5.4.2                    zlib   0.5.4.2              []
# zlib-bindings-0.1.1.5  zlib-bindings   0.1.1.5  [experimental]
# zlib-enum-0.2.3.1          zlib-enum   0.2.3.1  [experimental]
# zlib-lens-0.1.2            zlib-lens     0.1.2              []
#
#                                                               cabal-file  \
# AC-Vector-2.3.2        /home/giacamole/projects/memoria-haskell/stack...
# BlastHTTP-1.0.1        /home/giacamole/projects/memoria-haskell/stack...
# Boolean-0.2.3          /home/giacamole/projects/memoria-haskell/stack...
# BoundedChan-1.0.3.0    /home/giacamole/projects/memoria-haskell/stack...
# Cabal-1.18.1.5         /home/giacamole/projects/memoria-haskell/stack...
# ...                                                                  ...
# zip-archive-0.2.3.7    /home/giacamole/projects/memoria-haskell/stack...
# zlib-0.5.4.2           /home/giacamole/projects/memoria-haskell/stack...
# zlib-bindings-0.1.1.5  /home/giacamole/projects/memoria-haskell/stack...
# zlib-enum-0.2.3.1      /home/giacamole/projects/memoria-haskell/stack...
# zlib-lens-0.1.2        /home/giacamole/projects/memoria-haskell/stack...
#
#                                               categories  \
# AC-Vector-2.3.2        [data, math, numerical, graphics]
# BlastHTTP-1.0.1                         [bioinformatics]
# Boolean-0.2.3                                     [data]
# BoundedChan-1.0.3.0                        [concurrency]
# Cabal-1.18.1.5                            [distribution]
# ...                                                  ...
# zip-archive-0.2.3.7                              [codec]
# zlib-0.5.4.2                                     [codec]
# zlib-bindings-0.1.1.5                            [codec]
# zlib-enum-0.2.3.1       [codec, compression, enumerator]
# zlib-lens-0.1.2                                  [codec]
#
#                                                                     deps  \
# AC-Vector-2.3.2                                                   [base]
# BlastHTTP-1.0.1        [HTTP, base, biocore, blastxml, bytestring, co...
# Boolean-0.2.3                                                     [base]
# BoundedChan-1.0.3.0                                        [array, base]
# Cabal-1.18.1.5         [array, base, bytestring, containers, deepseq,...
# ...                                                                  ...
# zip-archive-0.2.3.7    [array, base, binary, bytestring, digest, dire...
# zlib-0.5.4.2                                          [base, bytestring]
# zlib-bindings-0.1.1.5                           [base, bytestring, zlib]
# zlib-enum-0.2.3.1      [base, bytestring, enumerator, transformers, z...
# zlib-lens-0.1.2                    [base, bytestring, profunctors, zlib]
#
#                                                         provided-modules  \
# AC-Vector-2.3.2        [Data.BoundingBox.B1, Data.BoundingBox.B2, Dat...
# BlastHTTP-1.0.1                                          [Bio.BlastHTTP]
# Boolean-0.2.3          [Data.Boolean, Data.Boolean.Numbers, Data.Bool...
# BoundedChan-1.0.3.0                     [Control.Concurrent.BoundedChan]
# Cabal-1.18.1.5         [Distribution.Compat.CopyFile, Distribution.Co...
# ...                                                                  ...
# zip-archive-0.2.3.7                                  [Codec.Archive.Zip]
# zlib-0.5.4.2           [Codec.Compression.GZip, Codec.Compression.Zli...
# zlib-bindings-0.1.1.5                  [Codec.Zlib, Codec.Zlib.Lowlevel]
# zlib-enum-0.2.3.1                                      [Codec.Zlib.Enum]
# zlib-lens-0.1.2                            [Codec.Compression.Zlib.Lens]
#
#                        src-dirs main-modules  mtl-direct  ...  \
# AC-Vector-2.3.2             [.]           []           0  ...
# BlastHTTP-1.0.1           [src]           []           1  ...
# Boolean-0.2.3             [src]           []           0  ...
# BoundedChan-1.0.3.0          []           []           0  ...
# Cabal-1.18.1.5               []           []           0  ...
# ...                         ...          ...         ...  ...
# zip-archive-0.2.3.7    [., src]     [Zip.hs]           1  ...
# zlib-0.5.4.2                 []           []           0  ...
# zlib-bindings-0.1.1.5        []           []           0  ...
# zlib-enum-0.2.3.1            []    [test.hs]           0  ...
# zlib-lens-0.1.2           [src]           []           0  ...
#
#                       Control.Monad.Trans.Writer.Lazy  \
# AC-Vector-2.3.2                                     0
# BlastHTTP-1.0.1                                     0
# Boolean-0.2.3                                       0
# BoundedChan-1.0.3.0                                 0
# Cabal-1.18.1.5                                      0
# ...                                               ...
# zip-archive-0.2.3.7                                 0
# zlib-0.5.4.2                                        0
# zlib-bindings-0.1.1.5                               0
# zlib-enum-0.2.3.1                                   0
# zlib-lens-0.1.2                                     0
#
#                       Control.Monad.Trans.Writer.Strict Control.Monad  \
# AC-Vector-2.3.2                                       0             0
# BlastHTTP-1.0.1                                       0             1
# Boolean-0.2.3                                         0             0
# BoundedChan-1.0.3.0                                   0             1
# Cabal-1.18.1.5                                        0             1
# ...                                                 ...           ...
# zip-archive-0.2.3.7                                   0             1
# zlib-0.5.4.2                                          0             1
# zlib-bindings-0.1.1.5                                 0             1
# zlib-enum-0.2.3.1                                     0             1
# zlib-lens-0.1.2                                       0             0
#
#                       System.IO Control.Monad.Trans.Control  \
# AC-Vector-2.3.2               0                           0
# BlastHTTP-1.0.1               0                           0
# Boolean-0.2.3                 0                           0
# BoundedChan-1.0.3.0           0                           0
# Cabal-1.18.1.5                1                           0
# ...                         ...                         ...
# zip-archive-0.2.3.7           1                           0
# zlib-0.5.4.2                  0                           0
# zlib-bindings-0.1.1.5         0                           0
# zlib-enum-0.2.3.1             1                           0
# zlib-lens-0.1.2               0                           0
#
#                       Control.Monad.Free  Control.Monad.Free.Ap  \
# AC-Vector-2.3.2                        0                      0
# BlastHTTP-1.0.1                        0                      0
# Boolean-0.2.3                          0                      0
# BoundedChan-1.0.3.0                    0                      0
# Cabal-1.18.1.5                         0                      0
# ...                                  ...                    ...
# zip-archive-0.2.3.7                    0                      0
# zlib-0.5.4.2                           0                      0
# zlib-bindings-0.1.1.5                  0                      0
# zlib-enum-0.2.3.1                      0                      0
# zlib-lens-0.1.2                        0                      0
#
#                        Control.Monad.Free.Church  Control.Monad.Free.Class  \
# AC-Vector-2.3.2                                0                         0
# BlastHTTP-1.0.1                                0                         0
# Boolean-0.2.3                                  0                         0
# BoundedChan-1.0.3.0                            0                         0
# Cabal-1.18.1.5                                 0                         0
# ...                                          ...                       ...
# zip-archive-0.2.3.7                            0                         0
# zlib-0.5.4.2                                   0                         0
# zlib-bindings-0.1.1.5                          0                         0
# zlib-enum-0.2.3.1                              0                         0
# zlib-lens-0.1.2                                0                         0
#
#                        Control.Monad.Free.TH
# AC-Vector-2.3.2                            0
# BlastHTTP-1.0.1                            0
# Boolean-0.2.3                              0
# BoundedChan-1.0.3.0                        0
# Cabal-1.18.1.5                             0
# ...                                      ...
# zip-archive-0.2.3.7                        0
# zlib-0.5.4.2                               0
# zlib-bindings-0.1.1.5                      0
# zlib-enum-0.2.3.1                          0
# zlib-lens-0.1.2                            0
#
# [1066 rows x 65 columns]
# ../../data/dfs/lts-3-22/lts-3-22.df
#                                                  package  version  \
# AC-Vector-2.3.2                                AC-Vector    2.3.2
# Agda-2.4.2.5                                        Agda  2.4.2.5
# BlastHTTP-1.2.0                                BlastHTTP    1.2.0
# BlogLiterately-0.8.1.3                    BlogLiterately  0.8.1.3
# BlogLiterately-diagrams-0.2.0.1  BlogLiterately-diagrams  0.2.0.1
# ...                                                  ...      ...
# zip-archive-0.2.3.7                          zip-archive  0.2.3.7
# zlib-0.5.4.2                                        zlib  0.5.4.2
# zlib-bindings-0.1.1.5                      zlib-bindings  0.1.1.5
# zlib-enum-0.2.3.1                              zlib-enum  0.2.3.1
# zlib-lens-0.1.2                                zlib-lens    0.1.2
#
#                                       stability  \
# AC-Vector-2.3.2                  [experimental]
# Agda-2.4.2.5                                 []
# BlastHTTP-1.2.0                              []
# BlogLiterately-0.8.1.3           [experimental]
# BlogLiterately-diagrams-0.2.0.1              []
# ...                                         ...
# zip-archive-0.2.3.7                          []
# zlib-0.5.4.2                                 []
# zlib-bindings-0.1.1.5            [experimental]
# zlib-enum-0.2.3.1                [experimental]
# zlib-lens-0.1.2                              []
#
#                                                                         cabal-file  \
# AC-Vector-2.3.2                  /home/giacamole/projects/memoria-haskell/stack...
# Agda-2.4.2.5                     /home/giacamole/projects/memoria-haskell/stack...
# BlastHTTP-1.2.0                  /home/giacamole/projects/memoria-haskell/stack...
# BlogLiterately-0.8.1.3           /home/giacamole/projects/memoria-haskell/stack...
# BlogLiterately-diagrams-0.2.0.1  /home/giacamole/projects/memoria-haskell/stack...
# ...                                                                            ...
# zip-archive-0.2.3.7              /home/giacamole/projects/memoria-haskell/stack...
# zlib-0.5.4.2                     /home/giacamole/projects/memoria-haskell/stack...
# zlib-bindings-0.1.1.5            /home/giacamole/projects/memoria-haskell/stack...
# zlib-enum-0.2.3.1                /home/giacamole/projects/memoria-haskell/stack...
# zlib-lens-0.1.2                  /home/giacamole/projects/memoria-haskell/stack...
#
#                                                         categories  \
# AC-Vector-2.3.2                  [data, math, numerical, graphics]
# Agda-2.4.2.5                                     [dependent types]
# BlastHTTP-1.2.0                                   [bioinformatics]
# BlogLiterately-0.8.1.3                                       [web]
# BlogLiterately-diagrams-0.2.0.1                              [web]
# ...                                                            ...
# zip-archive-0.2.3.7                                        [codec]
# zlib-0.5.4.2                                               [codec]
# zlib-bindings-0.1.1.5                                      [codec]
# zlib-enum-0.2.3.1                 [codec, compression, enumerator]
# zlib-lens-0.1.2                                            [codec]
#
#                                                                               deps  \
# AC-Vector-2.3.2                                                             [base]
# Agda-2.4.2.5                     [Agda, QuickCheck, array, base, base, binary, ...
# BlastHTTP-1.2.0                  [HTTP, base, biocore, biofasta, blastxml, byte...
# BlogLiterately-0.8.1.3           [BlogLiterately, HaXml, base, base, blaze-html...
# BlogLiterately-diagrams-0.2.0.1  [BlogLiterately, BlogLiterately-diagrams, Juic...
# ...                                                                            ...
# zip-archive-0.2.3.7              [array, base, binary, bytestring, digest, dire...
# zlib-0.5.4.2                                                    [base, bytestring]
# zlib-bindings-0.1.1.5                                     [base, bytestring, zlib]
# zlib-enum-0.2.3.1                [base, bytestring, enumerator, transformers, z...
# zlib-lens-0.1.2                              [base, bytestring, profunctors, zlib]
#
#                                                                   provided-modules  \
# AC-Vector-2.3.2                  [Data.BoundingBox.B1, Data.BoundingBox.B2, Dat...
# Agda-2.4.2.5                     [Agda.Auto.Auto, Agda.Auto.CaseSplit, Agda.Aut...
# BlastHTTP-1.2.0                                                    [Bio.BlastHTTP]
# BlogLiterately-0.8.1.3           [Paths_BlogLiterately, Text.BlogLiterately, Te...
# BlogLiterately-diagrams-0.2.0.1                     [Text.BlogLiterately.Diagrams]
# ...                                                                            ...
# zip-archive-0.2.3.7                                            [Codec.Archive.Zip]
# zlib-0.5.4.2                     [Codec.Compression.GZip, Codec.Compression.Zli...
# zlib-bindings-0.1.1.5                            [Codec.Zlib, Codec.Zlib.Lowlevel]
# zlib-enum-0.2.3.1                                                [Codec.Zlib.Enum]
# zlib-lens-0.1.2                                      [Codec.Compression.Zlib.Lens]
#
#                                                             src-dirs  \
# AC-Vector-2.3.2                                                  [.]
# Agda-2.4.2.5                     [src/agda-mode, src/full, src/main]
# BlastHTTP-1.2.0                                                [src]
# BlogLiterately-0.8.1.3                                   [main, src]
# BlogLiterately-diagrams-0.2.0.1                     [src, src/tools]
# ...                                                              ...
# zip-archive-0.2.3.7                                         [., src]
# zlib-0.5.4.2                                                      []
# zlib-bindings-0.1.1.5                                             []
# zlib-enum-0.2.3.1                                                 []
# zlib-lens-0.1.2                                                [src]
#
#                                          main-modules  mtl-direct  ...  \
# AC-Vector-2.3.2                                    []           0  ...
# Agda-2.4.2.5                       [Main.hs, Main.hs]           1  ...
# BlastHTTP-1.2.0                                    []           1  ...
# BlogLiterately-0.8.1.3            [BlogLiterately.hs]           1  ...
# BlogLiterately-diagrams-0.2.0.1  [BlogLiteratelyD.hs]           0  ...
# ...                                               ...         ...  ...
# zip-archive-0.2.3.7                          [Zip.hs]           1  ...
# zlib-0.5.4.2                                       []           0  ...
# zlib-bindings-0.1.1.5                              []           0  ...
# zlib-enum-0.2.3.1                           [test.hs]           0  ...
# zlib-lens-0.1.2                                    []           0  ...
#
#                                 Control.Monad.Trans.Writer.Lazy  \
# AC-Vector-2.3.2                                               0
# Agda-2.4.2.5                                                  0
# BlastHTTP-1.2.0                                               0
# BlogLiterately-0.8.1.3                                        0
# BlogLiterately-diagrams-0.2.0.1                               0
# ...                                                         ...
# zip-archive-0.2.3.7                                           0
# zlib-0.5.4.2                                                  0
# zlib-bindings-0.1.1.5                                         0
# zlib-enum-0.2.3.1                                             0
# zlib-lens-0.1.2                                               0
#
#                                 Control.Monad.Trans.Writer.Strict  \
# AC-Vector-2.3.2                                                 0
# Agda-2.4.2.5                                                    0
# BlastHTTP-1.2.0                                                 0
# BlogLiterately-0.8.1.3                                          0
# BlogLiterately-diagrams-0.2.0.1                                 0
# ...                                                           ...
# zip-archive-0.2.3.7                                             0
# zlib-0.5.4.2                                                    0
# zlib-bindings-0.1.1.5                                           0
# zlib-enum-0.2.3.1                                               0
# zlib-lens-0.1.2                                                 0
#
#                                 Control.Monad System.IO  \
# AC-Vector-2.3.2                             0         0
# Agda-2.4.2.5                                1         1
# BlastHTTP-1.2.0                             1         0
# BlogLiterately-0.8.1.3                      1         1
# BlogLiterately-diagrams-0.2.0.1             0         1
# ...                                       ...       ...
# zip-archive-0.2.3.7                         1         1
# zlib-0.5.4.2                                1         0
# zlib-bindings-0.1.1.5                       1         0
# zlib-enum-0.2.3.1                           1         1
# zlib-lens-0.1.2                             0         0
#
#                                 Control.Monad.Trans.Control  \
# AC-Vector-2.3.2                                           0
# Agda-2.4.2.5                                              0
# BlastHTTP-1.2.0                                           0
# BlogLiterately-0.8.1.3                                    0
# BlogLiterately-diagrams-0.2.0.1                           0
# ...                                                     ...
# zip-archive-0.2.3.7                                       0
# zlib-0.5.4.2                                              0
# zlib-bindings-0.1.1.5                                     0
# zlib-enum-0.2.3.1                                         0
# zlib-lens-0.1.2                                           0
#
#                                 Control.Monad.Free  Control.Monad.Free.Ap  \
# AC-Vector-2.3.2                                  0                      0
# Agda-2.4.2.5                                     0                      0
# BlastHTTP-1.2.0                                  0                      0
# BlogLiterately-0.8.1.3                           0                      0
# BlogLiterately-diagrams-0.2.0.1                  0                      0
# ...                                            ...                    ...
# zip-archive-0.2.3.7                              0                      0
# zlib-0.5.4.2                                     0                      0
# zlib-bindings-0.1.1.5                            0                      0
# zlib-enum-0.2.3.1                                0                      0
# zlib-lens-0.1.2                                  0                      0
#
#                                  Control.Monad.Free.Church  \
# AC-Vector-2.3.2                                          0
# Agda-2.4.2.5                                             0
# BlastHTTP-1.2.0                                          0
# BlogLiterately-0.8.1.3                                   0
# BlogLiterately-diagrams-0.2.0.1                          0
# ...                                                    ...
# zip-archive-0.2.3.7                                      0
# zlib-0.5.4.2                                             0
# zlib-bindings-0.1.1.5                                    0
# zlib-enum-0.2.3.1                                        0
# zlib-lens-0.1.2                                          0
#
#                                  Control.Monad.Free.Class  \
# AC-Vector-2.3.2                                         0
# Agda-2.4.2.5                                            0
# BlastHTTP-1.2.0                                         0
# BlogLiterately-0.8.1.3                                  0
# BlogLiterately-diagrams-0.2.0.1                         0
# ...                                                   ...
# zip-archive-0.2.3.7                                     0
# zlib-0.5.4.2                                            0
# zlib-bindings-0.1.1.5                                   0
# zlib-enum-0.2.3.1                                       0
# zlib-lens-0.1.2                                         0
#
#                                  Control.Monad.Free.TH
# AC-Vector-2.3.2                                      0
# Agda-2.4.2.5                                         0
# BlastHTTP-1.2.0                                      0
# BlogLiterately-0.8.1.3                               0
# BlogLiterately-diagrams-0.2.0.1                      0
# ...                                                ...
# zip-archive-0.2.3.7                                  0
# zlib-0.5.4.2                                         0
# zlib-bindings-0.1.1.5                                0
# zlib-enum-0.2.3.1                                    0
# zlib-lens-0.1.2                                      0
#
# [1352 rows x 65 columns]
# ../../data/dfs/lts-6-35/lts-6-35.df
#                                                  package  version  \
# AC-Vector-2.3.2                                AC-Vector    2.3.2
# Agda-2.5.1                                          Agda    2.5.1
# BlastHTTP-1.2.1                                BlastHTTP    1.2.1
# BlogLiterately-0.8.4.2                    BlogLiterately  0.8.4.2
# BlogLiterately-diagrams-0.2.0.5  BlogLiterately-diagrams  0.2.0.5
# ...                                                  ...      ...
# zlib-0.6.1.2                                        zlib  0.6.1.2
# zlib-bindings-0.1.1.5                      zlib-bindings  0.1.1.5
# zlib-enum-0.2.3.1                              zlib-enum  0.2.3.1
# zlib-lens-0.1.2.1                              zlib-lens  0.1.2.1
# zot-0.0.3                                            zot    0.0.3
#
#                                       stability  \
# AC-Vector-2.3.2                  [experimental]
# Agda-2.5.1                                   []
# BlastHTTP-1.2.1                              []
# BlogLiterately-0.8.4.2           [experimental]
# BlogLiterately-diagrams-0.2.0.5              []
# ...                                         ...
# zlib-0.6.1.2                                 []
# zlib-bindings-0.1.1.5            [experimental]
# zlib-enum-0.2.3.1                [experimental]
# zlib-lens-0.1.2.1                            []
# zot-0.0.3                        [experimental]
#
#                                                                         cabal-file  \
# AC-Vector-2.3.2                  /home/giacamole/projects/memoria-haskell/stack...
# Agda-2.5.1                       /home/giacamole/projects/memoria-haskell/stack...
# BlastHTTP-1.2.1                  /home/giacamole/projects/memoria-haskell/stack...
# BlogLiterately-0.8.4.2           /home/giacamole/projects/memoria-haskell/stack...
# BlogLiterately-diagrams-0.2.0.5  /home/giacamole/projects/memoria-haskell/stack...
# ...                                                                            ...
# zlib-0.6.1.2                     /home/giacamole/projects/memoria-haskell/stack...
# zlib-bindings-0.1.1.5            /home/giacamole/projects/memoria-haskell/stack...
# zlib-enum-0.2.3.1                /home/giacamole/projects/memoria-haskell/stack...
# zlib-lens-0.1.2.1                /home/giacamole/projects/memoria-haskell/stack...
# zot-0.0.3                        /home/giacamole/projects/memoria-haskell/stack...
#
#                                                         categories  \
# AC-Vector-2.3.2                  [data, math, numerical, graphics]
# Agda-2.5.1                                       [dependent types]
# BlastHTTP-1.2.1                                   [bioinformatics]
# BlogLiterately-0.8.4.2                                       [web]
# BlogLiterately-diagrams-0.2.0.5                              [web]
# ...                                                            ...
# zlib-0.6.1.2                                               [codec]
# zlib-bindings-0.1.1.5                                      [codec]
# zlib-enum-0.2.3.1                 [codec, compression, enumerator]
# zlib-lens-0.1.2.1                                          [codec]
# zot-0.0.3                                 [compilers/interpreters]
#
#                                                                               deps  \
# AC-Vector-2.3.2                                                             [base]
# Agda-2.5.1                       [Agda, EdisonAPI, EdisonCore, QuickCheck, arra...
# BlastHTTP-1.2.1                  [HTTP, base, biocore, biofasta, blastxml, byte...
# BlogLiterately-0.8.4.2           [BlogLiterately, HTTP, HaXml, base, base, blaz...
# BlogLiterately-diagrams-0.2.0.5  [BlogLiterately, BlogLiterately-diagrams, Juic...
# ...                                                                            ...
# zlib-0.6.1.2                                                    [base, bytestring]
# zlib-bindings-0.1.1.5                                     [base, bytestring, zlib]
# zlib-enum-0.2.3.1                [base, bytestring, enumerator, transformers, z...
# zlib-lens-0.1.2.1                            [base, bytestring, profunctors, zlib]
# zot-0.0.3                                                        [base, monads-tf]
#
#                                                                   provided-modules  \
# AC-Vector-2.3.2                  [Data.BoundingBox.B1, Data.BoundingBox.B2, Dat...
# Agda-2.5.1                       [Agda.Auto.Auto, Agda.Auto.CaseSplit, Agda.Aut...
# BlastHTTP-1.2.1                                                    [Bio.BlastHTTP]
# BlogLiterately-0.8.4.2           [Paths_BlogLiterately, Text.BlogLiterately, Te...
# BlogLiterately-diagrams-0.2.0.5                     [Text.BlogLiterately.Diagrams]
# ...                                                                            ...
# zlib-0.6.1.2                     [Codec.Compression.GZip, Codec.Compression.Zli...
# zlib-bindings-0.1.1.5                            [Codec.Zlib, Codec.Zlib.Lowlevel]
# zlib-enum-0.2.3.1                                                [Codec.Zlib.Enum]
# zlib-lens-0.1.2.1                                    [Codec.Compression.Zlib.Lens]
# zot-0.0.3                        [LambdaToSki, Parse, SKI, SkiToLambda, SkiToZo...
#
#                                                                           src-dirs  \
# AC-Vector-2.3.2                                                                [.]
# Agda-2.5.1                       [src/agda-ghc-names, src/agda-mode, src/full, ...
# BlastHTTP-1.2.1                                                              [src]
# BlogLiterately-0.8.4.2                                                 [main, src]
# BlogLiterately-diagrams-0.2.0.5                                   [src, src/tools]
# ...                                                                            ...
# zlib-0.6.1.2                                                                    []
# zlib-bindings-0.1.1.5                                                           []
# zlib-enum-0.2.3.1                                                               []
# zlib-lens-0.1.2.1                                                            [src]
# zot-0.0.3                                                                    [src]
#
#                                                           main-modules  \
# AC-Vector-2.3.2                                                     []
# Agda-2.5.1                       [Main.hs, Main.hs, agda-ghc-names.hs]
# BlastHTTP-1.2.1                                                     []
# BlogLiterately-0.8.4.2                             [BlogLiterately.hs]
# BlogLiterately-diagrams-0.2.0.5                   [BlogLiteratelyD.hs]
# ...                                                                ...
# zlib-0.6.1.2                                                        []
# zlib-bindings-0.1.1.5                                               []
# zlib-enum-0.2.3.1                                            [test.hs]
# zlib-lens-0.1.2.1                                                   []
# zot-0.0.3                                                     [zot.hs]
#
#                                  mtl-direct  ...  \
# AC-Vector-2.3.2                           0  ...
# Agda-2.5.1                                1  ...
# BlastHTTP-1.2.1                           1  ...
# BlogLiterately-0.8.4.2                    1  ...
# BlogLiterately-diagrams-0.2.0.5           0  ...
# ...                                     ...  ...
# zlib-0.6.1.2                              0  ...
# zlib-bindings-0.1.1.5                     0  ...
# zlib-enum-0.2.3.1                         0  ...
# zlib-lens-0.1.2.1                         0  ...
# zot-0.0.3                                 0  ...
#
#                                 Control.Monad.Trans.Writer.Lazy  \
# AC-Vector-2.3.2                                               0
# Agda-2.5.1                                                    0
# BlastHTTP-1.2.1                                               0
# BlogLiterately-0.8.4.2                                        0
# BlogLiterately-diagrams-0.2.0.5                               0
# ...                                                         ...
# zlib-0.6.1.2                                                  0
# zlib-bindings-0.1.1.5                                         0
# zlib-enum-0.2.3.1                                             0
# zlib-lens-0.1.2.1                                             0
# zot-0.0.3                                                     0
#
#                                 Control.Monad.Trans.Writer.Strict  \
# AC-Vector-2.3.2                                                 0
# Agda-2.5.1                                                      0
# BlastHTTP-1.2.1                                                 0
# BlogLiterately-0.8.4.2                                          0
# BlogLiterately-diagrams-0.2.0.5                                 0
# ...                                                           ...
# zlib-0.6.1.2                                                    0
# zlib-bindings-0.1.1.5                                           0
# zlib-enum-0.2.3.1                                               0
# zlib-lens-0.1.2.1                                               0
# zot-0.0.3                                                       0
#
#                                 Control.Monad System.IO  \
# AC-Vector-2.3.2                             0         0
# Agda-2.5.1                                  1         1
# BlastHTTP-1.2.1                             1         0
# BlogLiterately-0.8.4.2                      1         1
# BlogLiterately-diagrams-0.2.0.5             0         1
# ...                                       ...       ...
# zlib-0.6.1.2                                1         0
# zlib-bindings-0.1.1.5                       1         0
# zlib-enum-0.2.3.1                           1         1
# zlib-lens-0.1.2.1                           0         0
# zot-0.0.3                                   1         0
#
#                                 Control.Monad.Trans.Control  \
# AC-Vector-2.3.2                                           0
# Agda-2.5.1                                                0
# BlastHTTP-1.2.1                                           0
# BlogLiterately-0.8.4.2                                    0
# BlogLiterately-diagrams-0.2.0.5                           0
# ...                                                     ...
# zlib-0.6.1.2                                              0
# zlib-bindings-0.1.1.5                                     0
# zlib-enum-0.2.3.1                                         0
# zlib-lens-0.1.2.1                                         0
# zot-0.0.3                                                 0
#
#                                 Control.Monad.Free  Control.Monad.Free.Ap  \
# AC-Vector-2.3.2                                  0                      0
# Agda-2.5.1                                       0                      0
# BlastHTTP-1.2.1                                  0                      0
# ...
# zlib-bindings-0.1.1.5                                                 []
# zlib-clib-1.3.1                                                       []
# zot-0.0.3                                                       [zot.hs]
# zstd-0.1.3.0                                                          []
#
#                        mtl-direct  ... Control.Monad.Trans.Writer.Lazy  \
# AC-Angle-1.0                    0  ...                               0
# ALUT-2.4.0.3                    0  ...                               0
# ANum-0.2.0.4                    0  ...                               0
# AesonBson-0.4.1                 0  ...                               0
# Agda-2.8.0                      1  ...                               0
# ...                           ...  ...                             ...
# zlib-0.7.1.1                    0  ...                               0
# zlib-bindings-0.1.1.5           0  ...                               0
# zlib-clib-1.3.1                 0  ...                               0
# zot-0.0.3                       0  ...                               0
# zstd-0.1.3.0                    0  ...                               0
#
#                       Control.Monad.Trans.Writer.Strict Control.Monad  \
# AC-Angle-1.0                                          0             0
# ALUT-2.4.0.3                                          0             1
# ANum-0.2.0.4                                          0             0
# AesonBson-0.4.1                                       0             0
# Agda-2.8.0                                            0             1
# ...                                                 ...           ...
# zlib-0.7.1.1                                          0             1
# zlib-bindings-0.1.1.5                                 0             1
# zlib-clib-1.3.1                                       0             0
# zot-0.0.3                                             0             1
# zstd-0.1.3.0                                          0             0
#
#                       System.IO Control.Monad.Trans.Control  \
# AC-Angle-1.0                  0                           0
# ALUT-2.4.0.3                  1                           0
# ANum-0.2.0.4                  0                           0
# AesonBson-0.4.1               0                           0
# Agda-2.8.0                    1                           1
# ...                         ...                         ...
# zlib-0.7.1.1                  0                           0
# zlib-bindings-0.1.1.5         0                           0
# zlib-clib-1.3.1               0                           0
# zot-0.0.3                     0                           0
# zstd-0.1.3.0                  0                           0
#
#                       Control.Monad.Free  Control.Monad.Free.Ap  \
# AC-Angle-1.0                           0                      0
# ALUT-2.4.0.3                           0                      0
# ANum-0.2.0.4                           0                      0
# AesonBson-0.4.1                        0                      0
# Agda-2.8.0                             0                      0
# ...                                  ...                    ...
# zlib-0.7.1.1                           0                      0
# zlib-bindings-0.1.1.5                  0                      0
# zlib-clib-1.3.1                        0                      0
# zot-0.0.3                              0                      0
# zstd-0.1.3.0                           0                      0
#
#                        Control.Monad.Free.Church  Control.Monad.Free.Class  \
# AC-Angle-1.0                                   0                         0
# ALUT-2.4.0.3                                   0                         0
# ANum-0.2.0.4                                   0                         0
# AesonBson-0.4.1                                0                         0
# Agda-2.8.0                                     0                         0
# ...                                          ...                       ...
# zlib-0.7.1.1                                   0                         0
# zlib-bindings-0.1.1.5                          0                         0
# zlib-clib-1.3.1                                0                         0
# zot-0.0.3                                      0                         0
# zstd-0.1.3.0                                   0                         0
#
#                        Control.Monad.Free.TH
# AC-Angle-1.0                               0
# ALUT-2.4.0.3                               0
# ANum-0.2.0.4                               0
# AesonBson-0.4.1                            0
# Agda-2.8.0                                 0
# ...                                      ...
# zlib-0.7.1.1                               0
# zlib-bindings-0.1.1.5                      0
# zlib-clib-1.3.1                            0
# zot-0.0.3                                  0
# zstd-0.1.3.0                               0
#
# [3412 rows x 65 columns]
# ../../data/dfs/lts-24-37/lts-24-37.df
#                              package  version       stability  \
# AC-Angle-1.0                AC-Angle      1.0  [experimental]
# ALUT-2.4.0.3                    ALUT  2.4.0.3              []
# ANum-0.2.0.4                    ANum  0.2.0.4              []
# AesonBson-0.4.1            AesonBson    0.4.1  [experimental]
# Agda-2.8.0                      Agda    2.8.0              []
# ...                              ...      ...             ...
# zlib-0.7.1.1                    zlib  0.7.1.1              []
# zlib-bindings-0.1.1.5  zlib-bindings  0.1.1.5  [experimental]
# zlib-clib-1.3.1            zlib-clib    1.3.1              []
# zot-0.0.3                        zot    0.0.3  [experimental]
# zstd-0.1.3.0                    zstd  0.1.3.0              []
#
#                                                               cabal-file  \
# AC-Angle-1.0           /home/giacamole/projects/memoria-haskell/stack...
# ALUT-2.4.0.3           /home/giacamole/projects/memoria-haskell/stack...
# ANum-0.2.0.4           /home/giacamole/projects/memoria-haskell/stack...
# AesonBson-0.4.1        /home/giacamole/projects/memoria-haskell/stack...
# Agda-2.8.0             /home/giacamole/projects/memoria-haskell/stack...
# ...                                                                  ...
# zlib-0.7.1.1           /home/giacamole/projects/memoria-haskell/stack...
# zlib-bindings-0.1.1.5  /home/giacamole/projects/memoria-haskell/stack...
# zlib-clib-1.3.1        /home/giacamole/projects/memoria-haskell/stack...
# zot-0.0.3              /home/giacamole/projects/memoria-haskell/stack...
# zstd-0.1.3.0           /home/giacamole/projects/memoria-haskell/stack...
#
#                                      categories  \
# AC-Angle-1.0            [data, math, numerical]
# ALUT-2.4.0.3                            [sound]
# ANum-0.2.0.4                             [data]
# AesonBson-0.4.1                          [data]
# Agda-2.8.0                    [dependent types]
# ...                                         ...
# zlib-0.7.1.1                            [codec]
# zlib-bindings-0.1.1.5                   [codec]
# zlib-clib-1.3.1                         [codec]
# zot-0.0.3              [compilers/interpreters]
# zstd-0.1.3.0                            [codec]
#
#                                                                     deps  \
# AC-Angle-1.0                                                      [base]
# ALUT-2.4.0.3           [ALUT, OpenAL, StateVar, base, pretty, transfo...
# ANum-0.2.0.4                                                      [base]
# AesonBson-0.4.1        [aeson, attoparsec, base, bson, scientific, te...
# Agda-2.8.0             [Agda, STMonadTrans, aeson, ansi-terminal, arr...
# ...                                                                  ...
# zlib-0.7.1.1                                          [base, bytestring]
# zlib-bindings-0.1.1.5                           [base, bytestring, zlib]
# zlib-clib-1.3.1                                                       []
# zot-0.0.3                                              [base, monads-tf]
# zstd-0.1.3.0                       [base, bytestring, deepseq, ghc-prim]
#
#                                                         provided-modules  \
# AC-Angle-1.0                                                [Data.Angle]
# ALUT-2.4.0.3           [Sound.ALUT, Sound.ALUT.Config, Sound.ALUT.Con...
# ANum-0.2.0.4                                                 [Data.ANum]
# AesonBson-0.4.1               [Data.AesonBson, Data.AesonBson.Instances]
# Agda-2.8.0             [Agda.Benchmarking, Agda.Compiler.Backend, Agd...
# ...                                                                  ...
# zlib-0.7.1.1           [Codec.Compression.GZip, Codec.Compression.Zli...
# zlib-bindings-0.1.1.5                  [Codec.Zlib, Codec.Zlib.Lowlevel]
# zlib-clib-1.3.1                                                       []
# zot-0.0.3              [LambdaToSki, Parse, SKI, SkiToLambda, SkiToZo...
# zstd-0.1.3.0           [Codec.Compression.Zstd, Codec.Compression.Zst...
#
#                                                              src-dirs  \
# AC-Angle-1.0                                                      [.]
# ALUT-2.4.0.3                [examples/Basic, examples/TestSuite, src]
# ANum-0.2.0.4                                                    [src]
# AesonBson-0.4.1                                                   [.]
# Agda-2.8.0             [src/agda-mode, src/full, src/main, src/setup]
# ...                                                               ...
# zlib-0.7.1.1                                                       []
# zlib-bindings-0.1.1.5                                              []
# zlib-clib-1.3.1                                                    []
# zot-0.0.3                                                       [src]
# zstd-0.1.3.0                                                       []
#
#                                                             main-modules  \
# AC-Angle-1.0                                                          []
# ALUT-2.4.0.3           [HelloWorld.hs, OpenALInfo.hs, PlayFile.hs, Te...
# ANum-0.2.0.4                                                          []
# AesonBson-0.4.1                                                       []
# Agda-2.8.0                                            [Main.hs, Main.hs]
# ...                                                                  ...
# zlib-0.7.1.1                                                          []
# zlib-bindings-0.1.1.5                                                 []
# zlib-clib-1.3.1                                                       []
# zot-0.0.3                                                       [zot.hs]
# zstd-0.1.3.0                                                          []
#
#                        mtl-direct  ... Control.Monad.Trans.Writer.Lazy  \
# AC-Angle-1.0                    0  ...                               0
# ALUT-2.4.0.3                    0  ...                               0
# ANum-0.2.0.4                    0  ...                               0
# AesonBson-0.4.1                 0  ...                               0
# Agda-2.8.0                      1  ...                               0
# ...                           ...  ...                             ...
# zlib-0.7.1.1                    0  ...                               0
# zlib-bindings-0.1.1.5           0  ...                               0
# zlib-clib-1.3.1                 0  ...                               0
# zot-0.0.3                       0  ...                               0
# zstd-0.1.3.0                    0  ...                               0
#
#                       Control.Monad.Trans.Writer.Strict Control.Monad  \
# AC-Angle-1.0                                          0             0
# ALUT-2.4.0.3                                          0             1
# ANum-0.2.0.4                                          0             0
# AesonBson-0.4.1                                       0             0
# Agda-2.8.0                                            0             1
# ...                                                 ...           ...
# zlib-0.7.1.1                                          0             1
# zlib-bindings-0.1.1.5                                 0             1
# zlib-clib-1.3.1                                       0             0
# zot-0.0.3                                             0             1
# zstd-0.1.3.0                                          0             0
#
#                       System.IO Control.Monad.Trans.Control  \
# AC-Angle-1.0                  0                           0
# ALUT-2.4.0.3                  1                           0
# ANum-0.2.0.4                  0                           0
# AesonBson-0.4.1               0                           0
# Agda-2.8.0                    1                           1
# ...                         ...                         ...
# zlib-0.7.1.1                  0                           0
# zlib-bindings-0.1.1.5         0                           0
# zlib-clib-1.3.1               0                           0
# zot-0.0.3                     0                           0
# zstd-0.1.3.0                  0                           0
#
#                       Control.Monad.Free  Control.Monad.Free.Ap  \
# AC-Angle-1.0                           0                      0
# ALUT-2.4.0.3                           0                      0
# ANum-0.2.0.4                           0                      0
# AesonBson-0.4.1                        0                      0
# Agda-2.8.0                             0                      0
# ...                                  ...                    ...
# zlib-0.7.1.1                           0                      0
# zlib-bindings-0.1.1.5                  0                      0
# zlib-clib-1.3.1                        0                      0
# zot-0.0.3                              0                      0
# zstd-0.1.3.0                           0                      0
#
#                        Control.Monad.Free.Church  Control.Monad.Free.Class  \
# AC-Angle-1.0                                   0                         0
# ALUT-2.4.0.3                                   0                         0
# ANum-0.2.0.4                                   0                         0
# AesonBson-0.4.1                                0                         0
# Agda-2.8.0                                     0                         0
# ...                                          ...                       ...
# zlib-0.7.1.1                                   0                         0
# zlib-bindings-0.1.1.5                          0                         0
# zlib-clib-1.3.1                                0                         0
# zot-0.0.3                                      0                         0
# zstd-0.1.3.0                                   0                         0
#
#                        Control.Monad.Free.TH
# AC-Angle-1.0                               0
# ALUT-2.4.0.3                               0
# ANum-0.2.0.4                               0
# AesonBson-0.4.1                            0
# Agda-2.8.0                                 0
# ...                                      ...
# zlib-0.7.1.1                               0
# zlib-bindings-0.1.1.5                      0
# zlib-clib-1.3.1                            0
# zot-0.0.3                                  0
# zstd-0.1.3.0                               0
#
# [3422 rows x 65 columns]

# %% [markdown]
# In this section, we respond the following two questions:
# ​
# - How are packages distributed in stackage?
# - How are packages using mtl distributed in Stackage?
# ​
# For this, we make the following graphs
# ​
# 1. Line graph that shows the number of packets for each published snapshot over time
# 2. Bar graph that shows the evolution of the main categories of the packages
# 3. Bar graph that shows the evolution of the stabilities of the packages
# 4. Bar graph that shows the evolution of the main categories of the packages that depend of `mtl`
# 5. Bar graph that shows the evolution of the stabilities of the packages that depend of `mtl`
# ​
# ## RQ0. 1 - Line graph that shows the number of packets for each published snapshot over time

# %%
import re
def read_lines_code(fullpath):
    line_of_code = 0
    still_comment = 0
    file = open(fullpath,'r',encoding='latin-1')
    for idx,line in enumerate(file):
        no_space = line.strip()
        if no_space:
            big_comment = re.match("^({-[^#]*$)", no_space)
            if big_comment:
                still_comment += 1
                
            end_big_comment = re.match("[^#]*-}$", no_space)
            if end_big_comment:
                still_comment -= 1
                continue
            
            if still_comment != 0:
                continue
               
            comment = re.match("^\--+", no_space)
            if not comment and still_comment == 0:
                line_of_code += 1
                
    return line_of_code
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\-'
# <>:21: SyntaxWarning: invalid escape sequence '\-'
# /tmp/ipykernel_1015684/2078219159.py:21: SyntaxWarning: invalid escape sequence '\-'
#   comment = re.match("^\--+", no_space)

# %%
import math

def convert_size(size_bytes):
    if size_bytes == 0:
        return "0B"
    size_name = ("B", "KB", "MB", "GB", "TB", "PB", "EB", "ZB", "YB")
    i = int(math.floor(math.log(size_bytes, 1024)))
    p = math.pow(1024, i)
    s = round(size_bytes / p, 2)
    return "%s %s" % (s, size_name[i])

# %%
list_size = []
list_sizeMB = []
lts_list1 = ['19-11']
for idx,lts in enumerate(lts_list):
    size = 0
    sizeMB = 0
    folderpath = f'../../lts_downloaded/tar_package/lts-{lts}'
    print(folderpath)
    for path, dirs, files in os.walk(folderpath):
        for f in files:
            fp = os.path.join(path, f)
            sizeMB += os.stat(fp).st_size
            if f.lower().endswith('.hs'):
                try:
                    result = read_lines_code(fp)
                    size += result
                except Exception as e:
                    print('File ',fp,' with error: ',e)
    #Transform to MegaBytes          
    print("Folder LTS-" +str(lts)+ " LOC: " + str(size)+" size: " + str(convert_size(sizeMB)))
    list_size.append(size)
    list_sizeMB.append(sizeMB)
print("Las lts descargadas pesan: ",str(convert_size(sum(list_sizeMB))))

total_packages_all_lts = 0
for df in df_list:
    total_packages_all_lts += len(df)

print("El total numero de paquetes son: " + str(total_packages_all_lts)) 
print("Numero de Releases: " + str(len(df_list)))
# Out:
# ../../lts_downloaded/tar_package/lts-0-7
# Folder LTS-0-7 LOC: 1109053 size: 282.06 MB
# ../../lts_downloaded/tar_package/lts-2-22
# Folder LTS-2-22 LOC: 1642198 size: 433.58 MB
# ../../lts_downloaded/tar_package/lts-3-22
# Folder LTS-3-22 LOC: 1855326 size: 387.73 MB
# ../../lts_downloaded/tar_package/lts-6-35
# Folder LTS-6-35 LOC: 2930972 size: 760.0 MB
# ../../lts_downloaded/tar_package/lts-7-24
# Folder LTS-7-24 LOC: 3456514 size: 801.85 MB
# ../../lts_downloaded/tar_package/lts-9-21
# Folder LTS-9-21 LOC: 4007754 size: 759.08 MB
# ../../lts_downloaded/tar_package/lts-11-22
# Folder LTS-11-22 LOC: 3719707 size: 760.18 MB
# ../../lts_downloaded/tar_package/lts-12-14
# Folder LTS-12-14 LOC: 3683031 size: 795.11 MB
# ../../lts_downloaded/tar_package/lts-12-26
# Folder LTS-12-26 LOC: 3776028 size: 809.66 MB
# ../../lts_downloaded/tar_package/lts-13-11
# Folder LTS-13-11 LOC: 3272131 size: 715.91 MB
# ../../lts_downloaded/tar_package/lts-13-19
# Folder LTS-13-19 LOC: 3476488 size: 744.35 MB
# ../../lts_downloaded/tar_package/lts-14-27
# Folder LTS-14-27 LOC: 3598763 size: 857.77 MB
# ../../lts_downloaded/tar_package/lts-15-3
# Folder LTS-15-3 LOC: 3618452 size: 789.51 MB
# ../../lts_downloaded/tar_package/lts-16-11
# Folder LTS-16-11 LOC: 4179435 size: 899.61 MB
# ../../lts_downloaded/tar_package/lts-16-31
# Folder LTS-16-31 LOC: 4076514 size: 890.64 MB
# ../../lts_downloaded/tar_package/lts-17-2
# Folder LTS-17-2 LOC: 4156623 size: 850.98 MB
# ../../lts_downloaded/tar_package/lts-18-6
# Folder LTS-18-6 LOC: 4552855 size: 924.9 MB
# ../../lts_downloaded/tar_package/lts-18-8
# Folder LTS-18-8 LOC: 4554188 size: 925.09 MB
# ../../lts_downloaded/tar_package/lts-18-28
# Folder LTS-18-28 LOC: 4751866 size: 950.32 MB
# ../../lts_downloaded/tar_package/lts-19-33
# Folder LTS-19-33 LOC: 4504430 size: 971.4 MB
# ../../lts_downloaded/tar_package/lts-20-11
# Folder LTS-20-11 LOC: 4727733 size: 1.02 GB
# ../../lts_downloaded/tar_package/lts-20-12
# Folder LTS-20-12 LOC: 4728676 size: 1.02 GB
# ../../lts_downloaded/tar_package/lts-20-24
# Folder LTS-20-24 LOC: 4736416 size: 1.03 GB
# ../../lts_downloaded/tar_package/lts-20-26
# Folder LTS-20-26 LOC: 4738541 size: 1.03 GB
# ../../lts_downloaded/tar_package/lts-21-7
# Folder LTS-21-7 LOC: 4792336 size: 1.01 GB
# ../../lts_downloaded/tar_package/lts-21-11
# Folder LTS-21-11 LOC: 4790710 size: 1.01 GB
# ../../lts_downloaded/tar_package/lts-21-21
# Folder LTS-21-21 LOC: 4985688 size: 1.01 GB
# ../../lts_downloaded/tar_package/lts-21-25
# Folder LTS-21-25 LOC: 4988654 size: 1.02 GB
# ../../lts_downloaded/tar_package/lts-22-6
# Folder LTS-22-6 LOC: 8415690 size: 1.33 GB
# ../../lts_downloaded/tar_package/lts-22-20
# Folder LTS-22-20 LOC: 8147927 size: 1.32 GB
# ../../lts_downloaded/tar_package/lts-22-27
# Folder LTS-22-27 LOC: 8220197 size: 1.32 GB
# ../../lts_downloaded/tar_package/lts-22-43
# Folder LTS-22-43 LOC: 8237619 size: 1.33 GB
# ../../lts_downloaded/tar_package/lts-22-44
# Folder LTS-22-44 LOC: 7990637 size: 1.3 GB
# ../../lts_downloaded/tar_package/lts-23-28
# Folder LTS-23-28 LOC: 5468356 size: 1.1 GB
# ../../lts_downloaded/tar_package/lts-24-11
# Folder LTS-24-11 LOC: 6536182 size: 1.23 GB
# ../../lts_downloaded/tar_package/lts-24-37
# Folder LTS-24-37 LOC: 6636291 size: 1.24 GB
# Las lts descargadas pesan:  33.28 GB
# El total numero de paquetes son: 96843
# Numero de Releases: 36

# %%
total_pkgs = [len(df) for df in df_list]
lts_datetim=[]
for lts in lts_list:
    url = f"https://www.stackage.org/lts-{lts.replace('-','.')}"
    response = requests.get(url)
    my_date = find_date(response.content, extensive_search=True)
    date_time_obj = datetime.fromisoformat(my_date)
    lts_datetim.append(date_time_obj)
    
lts_date = ["2014-12"]
dates = [datetime(2014,12,1)]
year = 2015
for i in range (8):
    month = 0
    for i in range (4):
        month += 3
        date = str(year)+"-"+str(month)
        formato = datetime(year,month,1)
        lts_date.append(date)
        dates.append(formato)
    year += 1
    
dates = matplotlib.dates.date2num(dates)

# %%
register_matplotlib_converters()

fig, ax = plt.subplots(figsize=(18,6))
ax.margins(0.015) 
plt.subplots_adjust(right=1.1)


#line = ax.plot(dates, total_pkgs, color='grey', marker='o',label='lts version')
lns1 = ax.plot_date(lts_datetim, total_pkgs, linestyle='solid',color='black',label='LTS release')
plt.gcf().autofmt_xdate()

for i in range(len(lts_list)):
    if i == 3 or i == 17 or i == 14:
        plt.text(lts_datetim[i],total_pkgs[i]-350,lts_list[i],ha="center",rotation = -35)
    elif i== 12:
        plt.text(lts_datetim[i],total_pkgs[i]-280,lts_list[i],ha="center",rotation = -35)
    elif i== 16:
        plt.text(lts_datetim[i],total_pkgs[i]+150,lts_list[i],ha="center",rotation = 35)
    elif i== 21:
        plt.text(lts_datetim[i],total_pkgs[i]-350,lts_list[i],ha="center",rotation = -25)
    else:
        plt.text(lts_datetim[i],total_pkgs[i],lts_list[i],ha="center",rotation = 35)
    
ax2 = ax.twinx()
lns2 = ax2.plot_date(lts_datetim, list_size, linestyle='--',color='grey',label='LOC')

ax.set_yticks([0,500, 1000, 1500, 2000, 2500, 3000,3500])
ax.set_yticklabels(['0','500', '1000', '1500', '2000', '2500', '3000','3500'],fontsize=15)

ax2.set_yticks([0, 500000, 1000000, 1500000, 2000000, 2500000, 3000000, 3500000,4000000,4500000,5000000,5500000])
ax2.set_yticklabels(['0', '0.5 Mega','1.0 Mega', '1.5 Mega', '2.0 Mega', '2.5 Mega', '3.0 Mega', '3.5 Mega', '4.0 Mega', '4.5 Mega','5.0 Mega','5.5 Mega'],fontsize=15)

ax.set_xticks(dates)
ax.set_xticklabels(lts_date,fontsize=15)

ax.set_xlabel('Published date',fontsize=18)
ax.set_ylabel('Number of packages',fontsize=18)
ax2.set_ylabel('Lines of code',fontsize=18)

lns = lns1+lns2
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, loc='upper left')

plt.savefig("../../graphs/rq0-1.pdf", format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_1015684/1400181724.py:9: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   lns1 = ax.plot_date(lts_datetim, total_pkgs, linestyle='solid',color='black',label='LTS release')
# /tmp/ipykernel_1015684/1400181724.py:25: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   lns2 = ax2.plot_date(lts_datetim, list_size, linestyle='--',color='grey',label='LOC')
